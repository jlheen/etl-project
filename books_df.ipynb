# %%
import pandas as pd

# %%
file = 'books.csv'
bookpd_df = pd.read_csv(file)

# %%
bookpd_df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       3  Harry Potter and the Sorcerer's Stone (Harry P...
# 3       4  Harry Potter and the Chamber of Secrets (Harry...
# 4       5  Harry Potter and the Prisoner of Azkaban (Harr...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling-Mary GrandPré            4.56  0439785960  9780439785969
# 1  J.K. Rowling-Mary GrandPré            4.49  0439358078  9780439358071
# 2  J.K. Rowling-Mary GrandPré            4.47  0439554934  9780439554930
# 3                J.K. Rowling            4.41  0439554896  9780439554893
# 4  J.K. Rowling-Mary GrandPré            4.55  043965548X  9780439655484
#
#   language_code  # num_pages  ratings_count  text_reviews_count
# 0           eng          652        1944099               26249
# ...

# %%
clean_books_df = bookpd_df[['title', 'authors', 'average_rating', 'isbn', '# num_pages']]
clean_books_df.head()
# Out:
#                                                title  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2  Harry Potter and the Sorcerer's Stone (Harry P...
# 3  Harry Potter and the Chamber of Secrets (Harry...
# 4  Harry Potter and the Prisoner of Azkaban (Harr...
#
#                       authors  average_rating        isbn  # num_pages
# 0  J.K. Rowling-Mary GrandPré            4.56  0439785960          652
# 1  J.K. Rowling-Mary GrandPré            4.49  0439358078          870
# 2  J.K. Rowling-Mary GrandPré            4.47  0439554934          320
# 3                J.K. Rowling            4.41  0439554896          352
# 4  J.K. Rowling-Mary GrandPré            4.55  043965548X          435

# %%
# list of isbn numbers
# use splinter with browser.fill() 
# inspect the search bar element - fill with the isbn
# browser.find_by_name() in order to submit the request
# will take you to book's page
# then will do scraping as in mission_to_mars
# wrap it in try: except block, similar to weather api - if city not
# found, skipped
