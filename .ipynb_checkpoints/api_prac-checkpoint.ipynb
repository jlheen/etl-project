# %%
import requests
import pandas as pd
# from config import api_key
import json
from pprint import pprint

# %%
isbn_1 = '0439785960'

# %%
isbn_2 = '9780439785969'

# %%
url = 'https://openlibrary.org/api/books?'

# %%
# https://www.googleapis.com/books/v1/volumes?q=flowers+inauthor:keyes&key=yourAPIKey
query = f'{url}&format=json+bibkeys=ISBN:{isbn_1}'

# %%
response = requests.get(query)

# %%
print(response)
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-21-34c975fa6377> in <module>
# ----> 1 response.json()
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     887                 try:
#     888                     return complexjson.loads(
# --> 889                         self.content.decode(encoding), **kwargs
#     890                     )
#     891                 except UnicodeDecodeError:
#
# /opt/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /opt/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /opt/anaconda3/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
books = response.json()

# %%
pprint(books)
# Out:
# {'items': [{'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'US',
#                            'embeddable': True,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED_FOR_ACCESSIBILITY',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=JV-UDwAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#             'etag': 'LgMmycRLDK0',
#             'id': 'JV-UDwAAQBAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'An exuberantly illustrated '
#                                           'introduction to the early life of '
#                                           'abstract painter Vasya [Wassily] '
#                                           'Kadinsky describes how his creative '
#                                           'life was profoundly shaped by a '
#                                           'neurological condition called '
#                                           '&quot;synesthesia,&quot; which '
#                                           'caused him to experienced ...'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/JV-UDwAAQBAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Barb Rosenstock'],
#                            'averageRating': 4.5,
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/The_Noisy_Paint_Box.html?hl=&id=JV-UDwAAQBAJ',
#                            'categories': ['Juvenile Nonfiction'],
#                            'contentVersion': 'preview-1.0.0',
#                            'description': 'An exuberantly illustrated '
#                                           'introduction to the early life of '
#                                           'abstract painter Vasya [Wassily] '
#                                           'Kadinsky describes how his creative '
#                                           'life was profoundly shaped by a '
#                                           'neurological condition called '
#                                           '"synesthesia," which caused him to '
#                                           'experienced colors as sounds, and '
#                                           'sounds as colors.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=JV-UDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=JV-UDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9780307978486',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '0307978486',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'http://books.google.com/books?id=JV-UDwAAQBAJ&dq=9780439785969&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 33,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=JV-UDwAAQBAJ&printsec=frontcover&dq=9780439785969&hl=&cd=1&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2014',
#                            'publisher': 'Knopf Books for Young Readers',
#                            'ratingsCount': 14,
#                            'readingModes': {'image': False, 'text': False},
#                            'subtitle': "The Colors and Sounds of Kandinsky's "
#                                        'Abstract Art',
#                            'title': 'The Noisy Paint Box'}},
#            {'accessInfo': {'accessViewStatus': 'NONE',
#                            'country': 'US',
#                            'embeddable': False,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'NO_PAGES',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=_kzkswEACAAJ&hl=&printsec=frontcover&source=gbs_api'},
#             'etag': '+owztHxvwxE',
#             'id': '_kzkswEACAAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'Harry Potter Coloring BookBy '
#                                           'Scholastic'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/_kzkswEACAAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Scholastic'],
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/Harry_Potter_Coloring_Book.html?hl=&id=_kzkswEACAAJ',
#                            'contentVersion': 'preview-1.0.0',
#                            'description': 'Harry Potter Coloring BookBy '
#                                           'Scholastic',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=_kzkswEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=_kzkswEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '1548602655',
#                                                     'type': 'ISBN_10'},
#                                                    {'identifier': '9781548602659',
#                                                     'type': 'ISBN_13'}],
#                            'infoLink': 'http://books.google.com/books?id=_kzkswEACAAJ&dq=9780439785969&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 250,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=_kzkswEACAAJ&dq=9780439785969&hl=&cd=2&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2017-07-05',
#                            'publisher': 'Createspace Independent Publishing '
#                                         'Platform',
#                            'readingModes': {'image': False, 'text': False},
#                            'title': 'Harry Potter Coloring Book'}},
#            {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'US',
#                            'embeddable': True,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED_FOR_ACCESSIBILITY',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=kdLMDwAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#             'etag': 'G1QxtOWi8j4',
#             'id': 'kdLMDwAAQBAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'NEW YORK TIMES BESTSELLER * When a '
#                                           'single mom becomes an empty nester, '
#                                           'she spreads her wings to rediscover '
#                                           'herself--and her passions--in this '
#                                           'heartwarming novel from #1 New York '
#                                           'Times bestselling author Debbie '
#                                           'Macomber.'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/kdLMDwAAQBAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Debbie Macomber'],
#                            'averageRating': 3.5,
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/Window_on_the_Bay.html?hl=&id=kdLMDwAAQBAJ',
#                            'categories': ['Fiction'],
#                            'contentVersion': 'preview-1.0.0',
#                            'description': 
',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=oWObswEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=oWObswEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '1338246100',
#                                                     'type': 'ISBN_10'},
#                                                    {'identifier': '9781338246100',
#                                                     'type': 'ISBN_13'}],
#                            'infoLink': 'http://books.google.com/books?id=oWObswEACAAJ&dq=9780439785969&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 64,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=oWObswEACAAJ&dq=9780439785969&hl=&cd=6&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2018-01-10',
#                            'publisher': 'Scholastic Incorporated',
#                            'readingModes': {'image': False, 'text': False},
#                            'subtitle': 'Scratch Magic',
#                            'title': 'Hidden Hogwarts'}},
#            {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'US',
#                            'embeddable': True,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=Rzj3YdukI78C&hl=&printsec=frontcover&source=gbs_api'},
#             'etag': 'eEWDT0pouJ0',
#             'id': 'Rzj3YdukI78C',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'Recounts how the leopard got his '
#                                           'claws and teeth and why he rules '
#                                           'the forest with terror.'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/Rzj3YdukI78C',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Chinua Achebe',
#                                        'John Iroaganachi',
#                                        'Mary GrandPré'],
#                            'averageRating': 3.5,
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/How_the_Leopard_Got_His_Claws.html?hl=&id=Rzj3YdukI78C',
#                            'categories': ['Juvenile Fiction'],
#                            'contentVersion': '0.7.0.0.preview.0',
#                            'description': 'Recounts how the leopard got his '
#                                           'claws and teeth and why he rules '
#                                           'the forest with terror.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=Rzj3YdukI78C&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=Rzj3YdukI78C&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9780763648053',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '0763648051',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'http://books.google.com/books?id=Rzj3YdukI78C&dq=9780439785969&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 32,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=Rzj3YdukI78C&printsec=frontcover&dq=9780439785969&hl=&cd=7&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2011',
#                            'publisher': 'Candlewick Press',
#                            'ratingsCount': 2,
#                            'readingModes': {'image': False, 'text': False},
#                            'title': 'How the Leopard Got His Claws'}},
#            {'accessInfo': {'accessViewStatus': 'NONE',
#                            'country': 'US',
#                            'embeddable': False,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'NO_PAGES',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=S9a9NwAACAAJ&hl=&printsec=frontcover&source=gbs_api'},
#             'etag': '2xba0bjJDKs',
#             'id': 'S9a9NwAACAAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'Use your glow in the dark stickers '
#                                           'to complete the pages featuring '
#                                           'Dark Wizards and scenes involving '
#                                           'the Dark Arts from the film Harry '
#                                           'Potter and the Half Blood Prince.'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/S9a9NwAACAAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ["BBC CHILDREN'S BOOKS",
#                                        'British Broadcasting Corporation '
#                                        'Staff'],
#                            'averageRating': 5,
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/Glow_in_the_Dark.html?hl=&id=S9a9NwAACAAJ',
#                            'contentVersion': 'preview-1.0.0',
#                            'description': 'Use your glow in the dark stickers '
#                                           'to complete the pages featuring '
#                                           'Dark Wizards and scenes involving '
#                                           'the Dark Arts from the film Harry '
#                                           'Potter and the Half Blood Prince.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=S9a9NwAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=S9a9NwAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '1405904836',
#                                                     'type': 'ISBN_10'},
#                                                    {'identifier': '9781405904834',
#                                                     'type': 'ISBN_13'}],
#                            'infoLink': 'http://books.google.com/books?id=S9a9NwAACAAJ&dq=9780439785969&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 8,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=S9a9NwAACAAJ&dq=9780439785969&hl=&cd=8&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2009-05-28',
#                            'publisher': "BBC Children's Books",
#                            'ratingsCount': 5,
#                            'readingModes': {'image': False, 'text': False},
#                            'title': 'Glow in the Dark'}},
#            {'accessInfo': {'accessViewStatus': 'NONE',
#                            'country': 'US',
#                            'embeddable': False,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'NO_PAGES',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=9-W5tAEACAAJ&hl=&printsec=frontcover&source=gbs_api'},
#             'etag': '8mdsGq/aG4U',
#             'id': '9-W5tAEACAAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'The light reveals invisible ink '
#                                           'secrets on the fold-out map pages, '
#                                           'while the pen can help readers '
#                                           'create their own magical map, using '
#                                           'the blank parchment included at the '
#                                           'back of this book. Full color. '
#                                           'Consumable.'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/9-W5tAEACAAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Erinn Pascal'],
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/The_Marauder_s_Map.html?hl=&id=9-W5tAEACAAJ',
#                            'contentVersion': 'preview-1.0.0',
#                            'description': "Don't miss this guide to Hogwarts "
#                                           'that includes a wand-shaped '
#                                           'invisible ink pen with UV light, '
#                                           "fold-out pages of the Marauder's "
#                                           'Map, and a parchment to make your '
#                                           'own magical map!',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=9-W5tAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=9-W5tAEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '1338252801',
#                                                     'type': 'ISBN_10'},
#                                                    {'identifier': '9781338252804',
#                                                     'type': 'ISBN_13'}],
#                            'infoLink': 'http://books.google.com/books?id=9-W5tAEACAAJ&dq=9780439785969&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 52,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=9-W5tAEACAAJ&dq=9780439785969&hl=&cd=9&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2018-06-26',
#                            'publisher': 'Scholastic Incorporated',
#                            'readingModes': {'image': False, 'text': False},
#                            'title': "The Marauder's Map"}},
#            {'accessInfo': {'accessViewStatus': 'NONE',
#                            'country': 'US',
#                            'embeddable': False,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'NO_PAGES',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=xAqMngEACAAJ&hl=&printsec=frontcover&source=gbs_api'},
#             'etag': 'RdlJHpuTGqk',
#             'id': 'xAqMngEACAAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'Using simple concepts and '
#                                           'thought-provoking anecdotes, the '
#                                           'book explains how &#39;the '
#                                           'market&#39; evolved with humanity, '
#                                           'what was wrong with communism, what '
#                                           'the global financial crisis is '
#                                           'really about, the ways in which the '
#                                           'state spends your money ...'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/xAqMngEACAAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Dawie Roodt', 'Linette Retief'],
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/Tax_Lies_and_Red_Tape.html?hl=&id=xAqMngEACAAJ',
#                            'categories': ['Business forecasting'],
#                            'contentVersion': 'preview-1.0.0',
#                            'description': '"Find out why: It\'\'s wrong to '
#                                           'blame Wall Street bankers for the '
#                                           'global financial crisis; The '
#                                           'rhino-horn trade should be '
#                                           'legalised; Exempting anything from '
#                                           'VAT is a bad idea, even for the '
#                                           'poor; Job creation is a fruitless '
#                                           "exercise; South Africa's problem is "
#                                           'not poverty. Tax, Lies and Red Tape '
#                                           'is an insightful, '
#                                           'easy-to-understand, very '
#                                           'opinionated book about economics by '
#                                           "one of South Africa's most "
#                                           'experienced and controversial '
#                                           'economists. Dawie Roodt argues that '
#                                           'economics is not about numbers, '
#                                           'graphs and statistics; it is about '
#                                           'people, and about how they react to '
#                                           'incentives. Unfortunately, our '
#                                           'politicians seem to have forgotten '
#                                           'this. Using simple concepts and '
#                                           'thought-provoking anecdotes, the '
#                                           "book explains how 'the market' "
#                                           'evolved with humanity, what was '
#                                           'wrong with communism, what the '
#                                           'global financial crisis is really '
#                                           'about, the ways in which the state '
#                                           'spends your money (and the ways in '
#                                           'which it actually should), how tax '
#                                           'is collected, how money and '
#                                           'nflation really work, the ins and '
#                                           'outs of trade, and the ups and '
#                                           'downs of labour. In the process, '
#                                           'Roodt debunks politically correct '
#                                           'thinking and current government '
#                                           'policy, and suggests alternatives '
#                                           'for a more effective system. '
#                                           'Whether you agree with him or not, '
#                                           'Tax, Lies and Red Tape will get you '
#                                           'thinking about economics in a '
#                                           'completely new way."--Publisher '
#                                           'description.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=xAqMngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=xAqMngEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '1770224815',
#                                                     'type': 'ISBN_10'},
#                                                    {'identifier': '9781770224810',
#                                                     'type': 'ISBN_13'}],
#                            'infoLink': 'http://books.google.com/books?id=xAqMngEACAAJ&dq=9780439785969&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 221,
#                            'previewLink': 'http://books.google.com/books?id=xAqMngEACAAJ&dq=9780439785969&hl=&cd=10&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2014-04',
#                            'readingModes': {'image': False, 'text': False},
#                            'subtitle': 'Confessions of an Unreconstructed '
#                                        'Neoliberal Fundamentalist',
#                            'title': 'Tax, Lies and Red Tape'}}],
#  'kind': 'books#volumes',
#  'totalItems': 3535}

# %%
title_1 = books['items'][0]["volumeInfo"]["title"]
print(title_1)
# Out:
# The Noisy Paint Box

# %%
price = books['items'][0]['saleInfo']
print(price)
# Out:
# {'country': 'US', 'saleability': 'NOT_FOR_SALE', 'isEbook': False}

# %%
list_prices = []
rt_prices = []
Buy_link=[]
# loop through ISBN list, make requests and parse
for isbn in isbns:
	target_url=base_url+isbn
	reponse=requests.get(target+url).json()
        list_prices.append(reponse[0]['saleInfo']['listPrice']['amount'])
        re_prices.append(reponse[0]['retailPrice']['amount'])
